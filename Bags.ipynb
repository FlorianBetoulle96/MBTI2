# %%
import pandas as pd

# %%
def no_dupli(liste):
    return list(dict.fromkeys(liste))

# %%
very = ['amazingly', 'astoundingly', 'colossally', 'completely', 'dreadfully', 'especially',
         'exceptionally', 'excessively', 'extraordinarily', 'extremely', 'fantastically', 'frightfully', 'fully',
         'highly', 'incredibly', 'literally', 'mightily', 'outrageously', 'radically',
         'remarkably', 'strikingly', 'supremely', 'terribly', 'terrifically',
         'totally', 'uncommonly', 'unusually', 'utterly','excellent', 'exceptional', 'extraordinary', 'fantastic',
        'incredible','remarkable', 'sensational',
         'fabulous', 'marvelous', 'wonderful', 'superior', 'optimal', 'perfect', 'unparalleled', 'flawless',
        'amazing', 'magnificent', 'outstanding', 'superb',
         'phenomenal', 'terrific', 'splendid', 'great', 'awesome', 'impressive', 'sublime', 'first-rate', 'top-notch',
         'brilliant', 'stellar', 'exquisite', 'impeccable', 'elite', 'supreme', 'unbeatable', 'top-class', 'remarkable',
         'astounding', 'astonishing', 'breathtaking', 'glorious', 'grand', 'phenomenal', 'unparalleled', 
       'awesome', 'brilliant', 'excellent', 'exceptional', 'extraordinary', 'fantastic', 'great', 'incredible', 'outstanding',
        'remarkable', 'sensational', 'superb', 'terrific', 'wonderful', 'amazing', 'astonishing', 'awe-inspiring',
        'breathtaking', 'dazzling', 'fabulous', 'impressive', 'majestic', 'marvelous', 'mind-blowing', 'phenomenal',
        'splendid', 'stunning', 'sublime', 'top-notch', 'unbelievable', 'unforgettable', 'unparalleled', 'unreal',
        'remarkable', 'exquisite', 'stellar', 'perfect', 'flawless', 'supreme', 'first-rate', 'top-class', 'elite',
        'optimal', 'exemplary', 'formidable', 'glorious', 'grandiose', 'peerless', 'always',
       "love", "adore", "enjoy", "excited", "thrilled", "amazed", "inspired", "delighted", "impressed", "ecstatic",
        "cherish", "treasure", "celebrate", "embrace", "marvel", "revel", "savor", "laud", "applaud", "eager", "anticipate"
        , "fascinate", "enthuse", "gush", "rave", "amazing", "incredible", "fantastic", "awesome", "unbelievable",
        "phenomenal", "spectacular", "mind-blowing", "outstanding", "terrific", 'really',"Absolutely", "Incredibly",
        "Extremely", "Very", "Truly", "Remarkably", "Exceedingly", "Unbelievably", "Wonderfully", "Exceptionally",
        "Eagerly", "Passionately", "Enthusiastically", "Joyfully", "Excitedly", "Ecstatically", "Vividly", "Vigorously",
        "Wholeheartedly",'much','most','hell',"die","terrible",'worst','horrible','bigger']
very = no_dupli(very)
df_very = pd.DataFrame(very)
df_very.to_csv('Input/bags/very.csv', index=False)

me = ['i, im', 'me','my', 'myself']
me = no_dupli(me)
df_me = pd.DataFrame(me)
df_me.to_csv('Input/bags/me.csv', index=False)

you = ['you', 'youre', 'your']
you = no_dupli(you)
df_you = pd.DataFrame(you)
df_you.to_csv('Input/bags/you.csv', index=False)

yes = ['can','absolutely', 'accepted', 'acclaimed', 'accomplish', 'accomplishment', 'achievement', 'action', 'active', 'admire',
'adorable', 'adventure', 'affirmative', 'affluent', 'agree', 'agreeable', 'amazing', 'angelic', 'appealing', 'approve',
'aptitude', 'attractive', 'awesome',
'beaming', 'beautiful', 'believe', 'beneficial', 'bliss', 'bountiful', 'bounty', 'brave', 'bravo', 'brilliant', 'bubbly',
'calm', 'celebrated', 'certain', 'champ', 'champion', 'charming', 'cheery',
'commend', 'composed', 'congratulation', 'constant', 'cool', 'courageous', 'creative', 'cute',
'dazzling', 'delight', 'delightful', 'distinguished', 'divine',
'earnest', 'ecstatic', 'effective', 'effervescent', 'efficient', 'electrifying', 'elegant',
'enchanting', 'encouraging', 'endorsed', 'energetic', 'energized', 'engaging', 'enthusiastic', 'essential', 'esteemed',
'ethical', 'excellent', 'exciting', 'exquisite',
'fabulous', 'famous', 'fantastic', 'favorable', 'fetching', 'fine', 'fitting', 'flourishing', 'fortunate',
'free', 'fresh', 'friendly', 'fun', 'funny',
'generous', 'genius', 'genuine', 'giving', 'glamorous', 'glowing', 'good', 'gorgeous', 'graceful', 'great', 'grin',
'growing','handsome', 'happy', 'harmonious', 'healthy', 'hearty', 'heavenly', 'honest', 'honorable', 'honored',
'hug','idea', 'ideal', 'imaginative', 'imagine', 'impressive', 'innovate', 'innovative',
'instantaneous', 'instinctive', 'intellectual', 'intelligent', 'intuitive', 'inventive',
'jovial', 'joy', 'jubilant','keen', 'kind',
'laugh', 'learned', 'legendary', 'light', 'lively', 'lovely', 'lucid', 'lucky', 'luminous',
'marvelous', 'masterful', 'meaningful', 'merit', 'meritorious', 'miraculous', 'motivating', 'moving',
'nice', 'novel', 'nurturing', 'nutritious','okay', 'one', 'one-hundred percent', 'open', 'optimistic',
'paradise', 'perfect', 'phenomenal', 'pleasant', 'pleasurable', 'plentiful', 'poised', 'polished', 'popular', 'positive',
'powerful', 'pretty', 'principled', 'productive', 'progress', 'prominent', 'protected', 'proud',
'quality', 'reassuring', 'refined', 'refreshing', 'rejoice', 'remarkable', 'resounding', 'restored',
'satisfactory', 'secure', 'seemly', 'skilled', 'skillful',
'smile', 'soulful', 'sparkling', 'spirited', 'spiritual', 'stirring', 'stunning', 'stupendous', 'success',
'successful', 'sunny', 'super', 'superb', 'supporting', 'surprising',
'terrific', 'thrilling', 'thriving', 'top', 'trusting',
'truthful','unreal', 'unwavering', 'upstanding','valued', 'vibrant', 'victorious', 'victory',
'vigorous', 'virtuous', 'vital', 'vivacious','wealthy', 'welcome', 'well', 'whole', 'wholesome', 'willing', 'wonderful',
'wondrous', 'worthy', 'wow','yes', 'yummy','zeal', 'zealous']
df_yes = pd.DataFrame(yes)
df_yes.to_csv('Input/bags/yes.csv', index=False)

no =['na','no', 'dont','didnt','not','abysmal', 'adverse', 'alarming', 'angry', 'annoy', 'anxious',
'apathy', 'appalling', 'atrocious','awful', 'bad', 'banal', 'barbed', 'belligerent', 'bemoan', 'beneath', 'boring', 'broken',
'callous', "can't", 'clumsy', 'coarse', 'cold', 'cold-hearted', 'collapse', 'confused', 'contradictory', 'contrary',
'corrosive', 'corrupt', 'crazy', 'creepy', 'criminal', 'cruel', 'cry', 'cutting',
'damage', 'damaging', 'dastardly', 'dead', 'decaying', 'deformed', 'deny', 'deplorable', 'depressed', 'deprived',
'despicable', 'detrimental', 'dirty', 'disease', 'disgusting', 'disheveled', 'dishonest', 'dishonorable', 'dismal', 'distress',
'dreadful', 'dreary','enraged', 'eroding', 'evil',
'fail', 'faulty', 'fear', 'feeble', 'fight', 'filthy', 'foul', 'frighten', 'frightful',
'gawky', 'ghastly', 'grave', 'greed', 'grim', 'grimace', 'gross', 'grotesque', 'gruesome', 'guilty',
'haggard', 'hard', 'hard-hearted', 'harmful', 'hate', 'hideous', 'homely', 'horrendous', 'horrible', 'hostile',
'hurt', 'hurtful','icky', 'ignorant', 'ignore', 'ill', 'immature', 'imperfect', 'impossible', 'inane', 'inelegant',
'infernal', 'injure','injurious', 'insane', 'insidious', 'insipid','jealous', 'junky','lose', 'lousy', 'lumpy',
'malicious', 'mean', 'menacing', 'messy', 'misshapen', 'missing', 'misunderstood', 'moan', 'moldy', 'monstrous',
'naive', 'nasty', 'naughty', 'negate', 'negative', 'never', 'non', 'nobody', 'nondescript', 'nonsense', 'not', 'noxious',
'objectionable', 'odious', 'offensive', 'old', 'oppressive','pain', 'perturb', 'pessimistic', 'petty', 'plain', 'poisonous',
'poor', 'prejudice', 'questionable', 'quirky', 'quit', 'reject', 'renege', 'repellant', 'reptilian', 'repugnant', 'repulsive',
'revenge', 'revolting', 'rocky', 'rotten', 'rude', 'ruthless',
'sad', 'savage', 'scare', 'scary', 'scream', 'severe', 'shocking', 'shoddy', 'sick', 'sickening', 'sinister', 'slimy', 'smelly',
'sobbing', 'sorry', 'spiteful', 'sticky', 'stinky', 'stormy', 'stressful', 'stuck', 'stupid', 'substandard', 'suspect',
'suspicious','tense', 'terrible', 'terrifying', 'threatening',
'ugly', 'undermine', 'unfair', 'unfavorable', 'unhappy', 'unhealthy', 'unjust', 'unlucky', 'unpleasant', 'unsatisfactory',
'unsightly', 'untoward', 'unwanted', 'unwelcome', 'unwholesome', 'unwieldy', 'unwise', 'upset','vice', 'vicious', 'vile',
'villainous', 'vindictive','wary', 'weary', 'wicked', 'woeful', 'worthless', 'wound', 'yell', 'yucky']
no = no_dupli(no)
df_no = pd.DataFrame(no)
df_no.to_csv('Input/bags/no.csv', index=False)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

stopwords = set(stopwords.words('english'))
stopwords = {word.replace("'", "") for word in stopwords}

df_stopwords = pd.DataFrame(stopwords)
df_stopwords.to_csv('Input/Bags/stopwords.csv', index=False)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fbeto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fbeto\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# emotions = ['angry','oh','admire', 'best', 'afflict', 'afflict', 'agonize', 'alarm', 'alienate', 'amaze', 'amused', 'annoy', 
#             'appall', 'ashamed', 'awed', 'baffled', 'belittled', 'betrayed', 
#             'broken-down', 'broken-hearted', 'bullied', 'burdened', 'cast-aside', 
#             'compassionate', 'crush', 'dare', 'dazzled', 'dread', 'drained', 
#             'energetic', 'engross', 'enjoy', 'enthuse', 'excite', 'fascinate',
#             'harassed', 'happy', 'hate', 'heavy-hearted', 'helpless', 'humiliate', 'hurt', 'incapable',
#             'in-a-bind', 'in-disorder', 'in-effective', 'inferior', 'insecure', 'insulted',
#             'intimidated', 'jammed-up', 'jittery', 'jumpy',
#             'loathe', 'love', 'lousy', 'lucky', 'merry','mistreated','mourn', 'neglected',
#            'nervous', 'overjoyed', 'overlooked', 'panic', 'paralyze', 'passionate', 'peaceful', 'perplex', 'powerless',
#             ' pulled-apart', 'punished', 'puzzled', 'ready-to-explode', 'rejected', 'relax',
#            'relieved', 'rely', 'renewed', 'restrained', 'resent',
#             'rigid', 'scare', 'shamed', 'shocked', 'shunned', 
#             'stimulated', 'strained', 'stressed', 'stupefy', 'sulk', 'surprise', 'surprised', 
#             'terrified','terrify', 'threaten', 'thrill', 'thrilled', 'torture', 'trapped',
#             'uncertain', 'victimize',  
#             'weary', 'wounded', 'wow','ah', 'feel','huh','surprise','ohh','uhhuh','scared','ow','feels',
#             'exciting','sad', 'ohhh','boring','loved','tears','stress','hurts','scary'
#            ]
# think = ['analyze', 'contemplate', 'ponder', 'reflect', 'speculate', 'meditate', 'deliberate', 'ruminate',
#          'consider', 'evaluate', 'assess', 'examine', 'scrutinize', 'review', 'study', 'explore', 'weigh', 'conceive',
#          'devise', 'formulate', 'plan', 'design', 'scheme', 'plot', 'intend', 'purpose', 'decide', 'resolve', 'determine',
#          'conclude', 'infer', 'reason', 'deduce', 'cogitate', 'brood', 'daydream', 'fantasize', 'imagine', 'visualize',
#          'envision', 'brainstorm', 'create', 'innovate', 'invent', 'synthesize', 'compose', 'ponder', 'wonder', 
#         'think','suppose', 'focus', 'remember', 'recall', 'realize',  'write', 'organize', 'logical', 'mindset','mind',
#          'memory', 'aim', 'relate', 'rationalise', 'conjecture', 'understand', 'conceive', 'train', 'strategy',
#          "consider", "ponder", "reflect", "deliberate", "contemplate", "analyze", "evaluate", "weigh", "discern", "assess",
#          "scrutinize", "speculate", "meditate", "cautious", "judicious", "prudent", "thoughtful", "meticulous", "careful",
#          "measured", "reasoned", "conscientious", "mindful", "circumspect", "systematic"
#         ]

#essayer de voir les pourcentages séparés de chaque pour essayer de les changer
think = ["analyze", "logical", "critical", "systematic", "objective", "rational", "fair", "evaluate",
        "principle", "criteria", "efficient", "fact", "impersonal", "consistency", "truth","logic", "reason",
        "decide", "objective", "critique", "plan", "efficient", "fair", "result", "system", "evidence", "clear",
         "truth", "evaluate"]

emotions = ["feel", "believe", "value", "care", "important", "support", "help", "share", "together", "appreciate",
        "connect", "empathy", "kind", "respect", "love"
        "empathize", "value", "care", "important", "support", "nurture", "believe", "compassionate", "relationship",
        "considerate", "kindness", "harmony", "appreciate", "connect", "together"]

think = no_dupli(think)
df_think = pd.DataFrame(think)
df_think.to_csv('Input/Bags/think.csv', index=False)

emotions = no_dupli(emotions)
df_emotions = pd.DataFrame(emotions)
df_emotions.to_csv('Input/Bags/emotions.csv', index=False)

# %%
# perception = ["doubt", "guess", "wonder", "speculate", "assume", "suppose", "suspect", "question",
#               "estimate", "hypothesize", "consider", "ponder"
#              "maybe", "possibly", "probably", "perhaps", "likely", "potentially", "presumably",
#             "seems", "appears", "opinion", "could", "possible", "would",
#               'umm'
#            ]
# judgement = ["assert", "affirm", "declare", "state", "confirm", "emphasize", "guarantee", "insist",
#              "proclaim", "assure", "underscore",
#              "definitely", "certainly", "absolutely", "unquestionably", "undoubtedly", "confidently",
#              "firmly", "assuredly", "positively",
#              "certain", "sure", "clear", "doubt", "fact", "obvious", "guarantee"
# ]

judgement = ["decide", "organize", "plan", "scheduled", "order", "goal", "structured", "complete", "determine", "resolve",
             "finish", "systematic", "direct", "manage", "deadline"
             "plan", "schedule", "decide", "finish", "organize", "goal", "complete", "list", "deadline", "prepare",
             "structure", "determine", "arrange", "task", "done","assert", "affirm", "declare", "state", "confirm", "emphasize", "guarantee", "insist",
              "proclaim", "assure", "underscore",
              "definitely", "certainly", "absolutely", "unquestionably", "undoubtedly", "confidently",
              "firmly", "assuredly", "positively",
              "certain", "sure", "clear", "doubt", "fact", "obvious", "guarantee"]

perception = ["adapt", "explore", "open", "flexible", "improvise", "experience", "flow", "options", "discover",
              "curious", "change", "vary", "react", "unpredictable"
                "explore", "options", "discover", "open", "adapt", "spontaneous", "flexible", "change", "experience", "flow",
              "possibility", "improvise", "vary", "play", "doubt", "guess", "wonder", "speculate",
               "estimate", "hypothesize", 
             "maybe", "possibly", "probably", "perhaps", "likely", "potentially", "presumably",
            "seems", "appears", "could", "possible", "would",
              'umm']

perception = no_dupli(perception)
df_perception = pd.DataFrame(perception)
df_perception.to_csv('Input/Bags/perception.csv', index=False)

judgement = no_dupli(judgement)
df_judgement = pd.DataFrame(judgement)
df_judgement.to_csv('Input/Bags/judgement.csv', index=False)

# %%
extrav = ["together", "everyone", "party", "meet", "discuss", "call", "join", "exciting", "fun", "talk", "share",
          "team", "event", "friends","outgoing", "chat", "invite", "energetic", "group", "network", "connect", "celebrate",
          "public", "speak", "laugh", "engage", "activity", "dynamic", "community"
]

introv = ["observe", "noticed", 'think', 'feel'
]


extrav = no_dupli(extrav)
df_extrav = pd.DataFrame(extrav)
df_extrav.to_csv('Input/Bags/extrav.csv', index=False)

introv = no_dupli(introv)
df_introv = pd.DataFrame(introv)
df_introv.to_csv('Input/Bags/introv.csv', index=False)

# %%
intui = ["possibility", "idea", "ideas", "future", "vision", "imagine", "theory", "concept", "potential", "dream", "innovate",
         "connect", "pattern", "intuit", "inspire", "abstract","theory", "abstract",
         "innovative", "dream", "hypothesize", "visionary", "creative","create", "created",
         "potential", "possibilities", "insight", "intuitive"
]

sens = ["detail", "facts", "exact", "proof", "practical", "example", "clear",
        "step", "method", "data", "practical", "detail", "routine", "current", "concrete", "specific", "evidence",
        "observe", "present", "realistic", "accurate", "step-by-step", "methodical", "hands-on","use"
]


intui = no_dupli(intui)
df_intui = pd.DataFrame(intui)
df_intui.to_csv('Input/Bags/intui.csv', index=False)

sens = no_dupli(sens)
df_sens = pd.DataFrame(sens)
df_sens.to_csv('Input/Bags/sens.csv', index=False)

# %%
ideas = ['hey', 'people','now','time','god','should']
interjections = ['hey', 'um','uh',]
names = ['angela', 'charles', 'darryl', 'david', 'dwight', 'holly', 'jan', 'jim', 'karen', 'kelly', 'kevin', 'meredith',
         'oscar', 'pam', 'phyllis', 'roy', 'ryan', 'stanley', 'toby']

names = no_dupli(names)
df_names = pd.DataFrame(names)
df_names.to_csv('Input/Bags/names.csv', index=False)
